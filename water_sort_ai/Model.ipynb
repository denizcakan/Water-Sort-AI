# %% [markdown]
# # Install

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (2.1.1)
# Requirement already satisfied: torchvision in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (0.16.1)
# Requirement already satisfied: torchaudio in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (2.1.1)
# Requirement already satisfied: jinja2 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: fsspec in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch) (2023.12.1)
# Requirement already satisfied: numpy in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: requests in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: mpmath>=0.19 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 21.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\Deniz\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install stable-baselines3[extra] protobuf==3.20.*
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (2.2.1)
# Requirement already satisfied: protobuf==3.20.* in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (3.20.3)
# Requirement already satisfied: matplotlib in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: torch>=1.13 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: pandas in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: cloudpickle in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.26.2)
# Requirement already satisfied: pygame in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: pillow in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (10.1.0)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Requirement already satisfied: psutil in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (5.9.6)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: tqdm in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: rich in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (13.7.0)
# Requirement already satisfied: requests in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: click in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: importlib-resources in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]) (6.1.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: six>1.9 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.59.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.24.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Requirement already satisfied: sympy in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: filelock in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: networkx in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.12.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: colorama in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from click->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.46.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# WARNING: You are using pip version 21.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\Deniz\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install mss pydirectinput pytesseract gym
# Out:
# Requirement already satisfied: mss in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (9.0.1)
# Requirement already satisfied: pydirectinput in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (1.0.4)
# Requirement already satisfied: pytesseract in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (0.3.10)
# Requirement already satisfied: gym in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (0.26.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from pytesseract) (10.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gym) (1.26.2)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from gym) (7.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\deniz\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.17.0)
# WARNING: You are using pip version 21.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\Deniz\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
from mss import mss
import pydirectinput
import pytesseract
from matplotlib import pyplot as plt
import time
from gym import Env
from gym.spaces import Box, Discrete, MultiDiscrete, Tuple
import copy
import random
import pygame
import threading
import os 
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker
import sys
from IPython import display
# Out:
# WARNING:tensorflow:From C:\Users\Deniz\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def list_to_array(list):
    updated_list = []
    for sublist in list:
        updated_sublist = []
        for i in sublist:
            updated_sublist.append(i+1)
        updated_list.append(updated_sublist)
    for sublist in updated_list:
        while len(sublist)<4:
            sublist.append(0)
    while len(updated_list) < 8:
        updated_list.append([-1,-1,-1,-1])
    return np.array(updated_list)

# %%
def plot(scores, mean_scores):
    display.clear_output(wait=True)
    display.display(plt.gcf())
    plt.clf()
    plt.title('Training...')
    plt.xlabel('Number of Games')
    plt.ylabel('Score')
    plt.plot(scores)
    plt.plot(mean_scores)
    plt.ylim(ymin=-10)
    plt.text(len(scores)-1, scores[-1], str(scores[-1]))
    plt.text(len(mean_scores)-1, mean_scores[-1], str(mean_scores[-1]))
    plt.show(block=False)
    plt.pause(.1)

# %% [markdown]
# # Game

# %%
class WaterSortGame:
    def __init__(self):
        pygame.init()
        self.WIDTH = 500
        self.HEIGHT = 550
        self.screen = pygame.display.set_mode([self.WIDTH, self.HEIGHT])
        pygame.display.set_caption('Water Sort PyGame')
        self.font = pygame.font.Font('freesansbold.ttf', 24)
        self.fps = 120
        self.timer = pygame.time.Clock()
        self.color_choices = ['red', 'orange', 'light blue', 'dark blue', 'dark green', 'pink', 'purple', 'dark gray',
                              'brown', 'light green', 'yellow', 'white']
        self.tube_colors = []
        self.initial_colors = []
        self.tubes_number = 4
        self.new_game = True
        self.selected = False
        self.tube_rects = []
        self.select_rect = 100
        self.win = False
        self.level = 1
        self.zeros_ones = []
        self.previous_zeros_ones = self.zeros_ones
        self.current_zeros_ones = []
        self.reward = 0
        self.total_reward = 0

    def generate_start(self):
        self.tubes_number = random.randint(4, 8)
        if self.level == 1:
            self.tubes_number = 4
        tubes_colors = []
        available_colors = []
        for i in range(self.tubes_number):
            tubes_colors.append([])
            if i < self.tubes_number - 2:
                for j in range(4):
                    available_colors.append(i)
        for i in range(self.tubes_number - 2):
            for j in range(4):
                color = random.choice(available_colors)
                tubes_colors[i].append(color)
                available_colors.remove(color)
        #print(tubes_colors)
        #print(self.tubes_number)
        return tubes_colors

    def draw_tubes(self, tubes_num, tube_cols):
        tube_boxes = []
        if tubes_num % 2 == 0:
            tubes_per_row = tubes_num // 2
            offset = False
        else:
            tubes_per_row = tubes_num // 2 + 1
            offset = True
        spacing = self.WIDTH / tubes_per_row
        for i in range(tubes_per_row):
            for j in range(len(tube_cols[i])):
                pygame.draw.rect(self.screen, self.color_choices[tube_cols[i][j]], [5 + spacing * i, 200 - (50 * j), 65, 50], 0, 3)
            box = pygame.draw.rect(self.screen, 'blue', [5 + spacing * i, 50, 65, 200], 5, 5)
            if self.select_rect == i:
                pygame.draw.rect(self.screen, 'green', [5 + spacing * i, 50, 65, 200], 3, 5)
            tube_boxes.append(box)
        if offset:
            for i in range(tubes_per_row - 1):
                for j in range(len(tube_cols[i + tubes_per_row])):
                    pygame.draw.rect(self.screen, self.color_choices[tube_cols[i + tubes_per_row][j]],
                                     [(spacing * 0.5) + 5 + spacing * i, 450 - (50 * j), 65, 50], 0, 3)
                box = pygame.draw.rect(self.screen, 'blue', [(spacing * 0.5) + 5 + spacing * i, 300, 65, 200], 5, 5)
                if self.select_rect == i + tubes_per_row:
                    pygame.draw.rect(self.screen, 'green', [(spacing * 0.5) + 5 + spacing * i, 300, 65, 200], 3, 5)
                tube_boxes.append(box)
        else:
            for i in range(tubes_per_row):
                for j in range(len(tube_cols[i + tubes_per_row])):
                    pygame.draw.rect(self.screen, self.color_choices[tube_cols[i + tubes_per_row][j]], [5 + spacing * i,
                                                                                              450 - (50 * j), 65, 50], 0, 3)
                box = pygame.draw.rect(self.screen, 'blue', [5 + spacing * i, 300, 65, 200], 5, 5)
                if self.select_rect == i + tubes_per_row:
                    pygame.draw.rect(self.screen, 'green', [5 + spacing * i, 300, 65, 200], 3, 5)
                tube_boxes.append(box)
        return tube_boxes

    def calc_move(self, colors, selected_rect, destination):

        self.check_fullcolor()
        current = self.zeros_ones
        
        
        chain = True
        color_on_top = 100
        length = 1
        color_to_move = 100
        if len(colors[selected_rect]) > 0:
            color_to_move = colors[selected_rect][-1]
            for i in range(1, len(colors[selected_rect])):
                if chain:
                    if colors[selected_rect][-1 - i] == color_to_move:
                        length += 1
                    else:
                        chain = False
        if 4 > len(colors[destination]):
            if len(colors[destination]) == 0:
                color_on_top = color_to_move
            else:
                color_on_top = colors[destination][-1]
        if color_on_top == color_to_move:
            for i in range(length):
                if len(colors[destination]) < 4:
                    if len(colors[selected_rect]) > 0:
                        colors[destination].append(color_on_top)
                        colors[selected_rect].pop(-1)
        self.check_fullcolor()
        next = self.zeros_ones
        #print(current)
        #print(next)
        #print(self.get_reward(current, next))
        #print(colors, length)
        return colors


    def run_game(self):
        run = True
        while run:
            self.screen.fill('black')
            self.timer.tick(self.fps)
            if self.new_game:
                self.tube_colors = self.generate_start()
                self.initial_colors = copy.deepcopy(self.tube_colors)
                self.new_game = False
                self.zeros_ones = [0] * (self.tubes_number -2)
            else:
                self.tube_rects = self.draw_tubes(self.tubes_number, self.tube_colors)
            self.win = self.check_victory(self.tube_colors)
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    run = False  
                elif event.type == pygame.KEYDOWN and event.key == pygame.K_q: # burda değişiklik
                    run = False # burda değişiklik
                if event.type == pygame.KEYUP:
                    if event.key == pygame.K_SPACE:
                        self.tube_colors = copy.deepcopy(self.initial_colors)
                    elif event.key == pygame.K_RETURN:
                        self.new_game = True
                        self.level += 1  # Leveli bir arttır
                        """if self.level > 40:
                            self.tubes_number = 8
                        elif self.level > 30:
                            self.tubes_number = 7
                        elif self.level > 20:
                            self.tubes_number = 6
                        elif self.level > 10:
                            self.tubes_number = 5"""
                            
                if event.type == pygame.KEYDOWN:

                    if not self.selected:
                        if event.key == pygame.K_1:
                            self.select_rect = 0
                            self.selected = True
                        elif event.key == pygame.K_2:
                            self.select_rect = 1
                            self.selected = True
                        elif event.key == pygame.K_3:
                            self.select_rect = 2
                            self.selected = True
                        elif event.key == pygame.K_4:
                            self.select_rect = 3
                            self.selected = True
                        elif event.key == pygame.K_5:
                            self.select_rect = 4
                            self.selected = True
                        elif event.key == pygame.K_6:
                            self.select_rect = 5
                            self.selected = True
                        elif event.key == pygame.K_7:
                            self.select_rect = 6
                            self.selected = True
                        elif event.key == pygame.K_8:
                            self.select_rect = 7
                            self.selected = True
                        elif event.key == pygame.K_9:
                            self.select_rect = 8
                            self.selected = True
                        """for item in range(len(self.tube_rects)):
                            if self.tube_rects[item].collidepoint(event.pos):
                                self.selected = True
                                self.select_rect = item"""
                    else:

                        if event.key == pygame.K_1:
                            dest_rect = 0
                        elif event.key == pygame.K_2:
                            dest_rect = 1
                        elif event.key == pygame.K_3:
                            dest_rect = 2
                        elif event.key == pygame.K_4:
                            dest_rect = 3
                        elif event.key == pygame.K_5:
                            dest_rect = 4
                        elif event.key == pygame.K_6:
                            dest_rect = 5
                        elif event.key == pygame.K_7:
                            dest_rect = 6
                        elif event.key == pygame.K_8:
                            dest_rect = 7
                        elif event.key == pygame.K_9:
                            dest_rect = 8

                        
                        
                        """for item in range(len(self.tube_rects)):
                            if self.tube_rects[item].collidepoint(event.pos):
                                dest_rect = item"""
                        self.tube_colors = self.calc_move(self.tube_colors, self.select_rect, dest_rect)
                        self.selected = False
                        self.select_rect = 100

            self.display_texts()
            self.display_level()
            self.display_reward()# Yeni eklenen fonksiyonu çağır
            pygame.display.flip()

        pygame.quit()
        sys.exit() # burda değişiklik

    def display_texts(self):
        if self.win:
            victory_text = self.font.render('You Won! Press Enter for a new board!', True, 'white')
            self.screen.blit(victory_text, (30, 265))
        restart_text = self.font.render('Stuck? Space-Restart, Enter-New Board!', True, 'white')
        self.screen.blit(restart_text, (10, 10))

    def display_level(self):
        level_text = self.font.render(f'Level: {self.level}', True, 'white')
        text_rect = level_text.get_rect(topleft=(10, self.HEIGHT - 30))  # Update topleft instead of center
        self.screen.blit(level_text, text_rect)

    def display_reward(self):
        reward_text = self.font.render(f'Reward: {self.reward}', True, 'white')
        text_rect = reward_text.get_rect(topleft=(250, self.HEIGHT - 30))  # Update topleft instead of center
        self.screen.blit(reward_text, text_rect)
    
    def check_fullcolor(self):
    
        for i in self.tube_colors:
            if len(i) == 4:
                if all(x == i[0] for x in i):
                    self.zeros_ones[i[0]] = 1
                
        return self.zeros_ones
        

    def check_victory(self, colors):
        won = True
        for i in range(len(colors)):
            if len(colors[i]) > 0:
                if len(colors[i]) != 4:
                    won = False
                else:
                    main_color = colors[i][-1]
                    for j in range(len(colors[i])):
                        if colors[i][j] != main_color:
                            won = False
        return won

    def get_reward(self, current, next):
        self.reward = 0
        #print(current, next)
    
        for i in range(len(current)):
            # Mevcut durumda 0 iken, bir sonraki durumda 1 olduysa 10 puan ekle
            if current[i] == 0 and next[i] == 1:
                self.reward += 10
    
        return self.reward

# %% [markdown]
# # Agent

# %%
class Agent(Env):
    def __init__(self):
        super().__init__()
        self.plot_scores = []
        self.mean_score = []
        self.total_score = 0
        plt.ion()

        self.game = None
        self.game_thread = threading.Thread(target=self.run_game_in_thread)
        self.game_thread.daemon = True  # Bu, program sonlandığında thread'in de sonlanmasını sağlar
        self.game_thread.start()

        self.level = 1
        self.action_space = MultiDiscrete([8, 8])
        self.action_number = 0
        self.invalid_action_counter = 0
        self.last_three_observation = []
        self.observation_space = Box(low=-1, high=6, shape=(8, 4), dtype=int)

    def step(self, action):
        self.action_number += 1
        action_type = None
        reward = 0
        done = False
        info = {}
        if len(self.last_three_observation) == 0:
            self.last_three_observation.append(self.get_observation())
        obs_list = copy.deepcopy(self.last_three_observation)



        if self.game.win == False:
            if len(obs_list[-1]) > max(action[0], action[1]):
                pydirectinput.press(str(action[0]+1))
                #time.sleep(0.1)
                pydirectinput.press(str(action[1]+1))
        

        
        observation = copy.deepcopy(self.get_observation())
        
        if self.game.win:
            reward = 10 # Get reward
            self.game.reward += reward
            done = True
            pydirectinput.press("enter")
            time.sleep(0.3)
            action_type = "WON"

        
        else:
            if len(obs_list) == 4:
                obs_list.pop(0)

            if action[0] == action[1]:
                reward = -1
                action_type = "Select=Destination"
                self.invalid_action_counter += 1

            elif sorted(obs_list[-1]) == sorted(observation):
                reward = -1
                action_type = "Not Changed"
                self.invalid_action_counter += 1

            elif len(obs_list) == 2 and sorted(obs_list[-2]) == sorted(observation):
                reward = -1
                action_type = "Iteration"
                self.invalid_action_counter += 1

            elif len(obs_list) == 3 and (sorted(obs_list[-2]) == sorted(observation) or sorted(obs_list[-3]) == sorted(observation)):
                reward = -1
                action_type = "Iteration"
                self.invalid_action_counter += 1

            elif self.check_fullcolor(observation) > self.check_fullcolor(obs_list[-1]):
                reward = 5
                action_type = "Fullcolor"
                obs_list.append(observation)
                #self.invalid_action_counter = 0

            else:
                reward = 1
                action_type = "Valid Action"
                obs_list.append(observation)
                #self.invalid_action_counter = 0
            self.game.reward += reward
        
        if done == False:
            done = self.get_done()
        self.last_three_observation = copy.deepcopy(obs_list)
        self.level = self.game.level
        #print(action, action_type, "ActionCounter:", self.action_number)
        #print(observation)
        #print(list_to_array(observation))
        #print()
        return list_to_array(observation), reward, done, info
    
    def render(self):
        pass

    def reset(self):
        
        if self.level != 1:
            self.total_score += self.game.reward
            self.plot_scores.append(self.game.reward)
            self.mean_score.append(self.total_score/(self.level-1))
            plot(env.plot_scores, env.mean_score)
        #print(self.level)
        self.game.reward = 0
        observation = self.get_observation()
        #print(observation)
        #print()
        self.action_number = 0
        self.invalid_action_counter = 0
        self.last_three_observation = []
        self.previous_action = None
        
        pydirectinput.press("space")

        return list_to_array(observation)

    def close(self):   #ok
        cv2.destroyAllWindows()

    def get_done(self):
        done = False
        if self.invalid_action_counter == 10:
            done = True
            pydirectinput.press("enter")
        return done

    def get_observation(self):
        obs = self.game.tube_colors
        return obs

    def run_game_in_thread(self):
        self.game = WaterSortGame()
        self.game.run_game()

    def check_fullcolor(self, obs):
        x = 0
        for i in obs:
            if len(i) == 4:
                if all(x == i[0] for x in i):
                    x += 1
        return x

# %%
env = Agent()

# %%
env = Agent()
time.sleep(6)
for episode in range(5):
    obs = env.reset()
    done = False  
    total_reward   = 0
    while not done: 
        obs, reward,  done, info =  env.step(env.action_space.sample())
        total_reward  += reward
    #print('Total Reward for episode {} is {}'.format(episode, total_reward))

# %% [markdown]
# # A2C

# %%
from stable_baselines3 import DQN, A2C, PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_vec_env
import time

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

CHECKPOINT_DIR = "./train/"
LOG_DIR = "./logs/"

callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
import time
start_time = time.time()


env = Agent()
time.sleep(4)
model = A2C('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
model.learn(total_timesteps=10000, callback=callback)


finish_time = time.time()
time = finish_time - start_time

hours = int(time // 3600)
minutes = int((time % 3600) // 60)
seconds = int(time % 60)

print("Time for learning: {} hours, {} minutes, {} seconds".format(hours, minutes, seconds))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 8
#       6 time.sleep(4)
#       7 model = A2C('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
# ----> 8 model.learn(total_timesteps=10000, callback=callback)
#      11 finish_time = time.time()
#      12 time = finish_time - start_time
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\a2c\a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\shimmy\openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# Cell In[9], line 35, in Agent.step(self, action)
#      33 if self.game.win == False:
#      34     if len(obs_list[-1]) > max(action[0], action[1]):
# ---> 35         pydirectinput.press(str(action[0]+1))
#      36         #time.sleep(0.1)
#      37         pydirectinput.press(str(action[1]+1))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pydirectinput\__init__.py:242, in _genericPyDirectInputChecks.<locals>.wrapper(*args, **kwargs)
#     239 funcArgs = inspect.getcallargs(wrappedFunction, *args, **kwargs)
#     241 failSafeCheck()
# --> 242 returnVal = wrappedFunction(*args, **kwargs)
#     243 _handlePause(funcArgs.get("_pause"))
#     244 return returnVal
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pydirectinput\__init__.py:545, in press(keys, presses, interval, logScreenshot, _pause)
#     543 failSafeCheck()
#     544 downed = keyDown(k)
# --> 545 upped = keyUp(k)
#     546 # Count key press as complete if key was "downed" and "upped" successfully
#     547 if downed and upped:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pydirectinput\__init__.py:243, in _genericPyDirectInputChecks.<locals>.wrapper(*args, **kwargs)
#     241 failSafeCheck()
#     242 returnVal = wrappedFunction(*args, **kwargs)
# --> 243 _handlePause(funcArgs.get("_pause"))
#     244 return returnVal
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pydirectinput\__init__.py:232, in _handlePause(_pause)
#     230 if _pause:
#     231     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 232     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %%
model.save('train_first/A2C_MLP_10K_vers6')

# %%
del model

# %%
a2c_10k_model = A2C.load('train_first/A2C_MLP_10K_vers6.zip')

# %%
# Check model with predicted actions

import time
total_action_number = 0
for episode in range(3): 
    action_counter = 0
    env = Agent()
    time.sleep(2)
    obs = env.reset()
    while env.level < 3: 
        action, _ = a2c_10k_model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.01)
        action_counter += 1
    print('Episode {} ===> Total number of actions to get level 3 is {}'.format(episode+1, action_counter))
    pydirectinput.press("q")
print('Mean number of actions to get level 3 is {}'.format(total_action_number//3))
# Out:
# Episode 1 ===> Total number of actions to get level 3 is 146
# Episode 2 ===> Total number of actions to get level 3 is 145
# Episode 3 ===> Total number of actions to get level 3 is 282
# Mean number of actions to get level 3 is 0

# %% [markdown]
# # PPO

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

CHECKPOINT_DIR = "./train/"
LOG_DIR = "./logs/"

from stable_baselines3 import DQN, A2C, PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_vec_env
import time

callback = TrainAndLoggingCallback(check_freq=500, save_path=CHECKPOINT_DIR)

# %%
import time
start_time = time.time()


env = Agent()
time.sleep(4)
model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
model.learn(total_timesteps=5000, callback=callback)


finish_time = time.time()
time = finish_time - start_time

hours = int(time // 3600)
minutes = int((time % 3600) // 60)
seconds = int(time % 60)

print("Kodun çalışma süresi: {} saat, {} dakika, {} saniye".format(hours, minutes, seconds))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 1
# Logging to ./logs/PPO_1
# 1
# 1
# 2
# 3
# 4
# 5
# 5
# 5
# 5
# 5
# 6
# 7
# 8
# 9
# 9
# 10
# 11
# 11
# 11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.9     |
# |    ep_rew_mean     | -35.2    |
# | time/              |          |
# |    fps             | 5        |
# |    iterations      | 1        |
# |    time_elapsed    | 363      |
# |    total_timesteps | 2048     |
# ---------------------------------
# 12
# 12
# 13
# 13
# 13
# 14
# 14
# 14
# 14
# 15
# 15
# 16
# 17
# 17
# 17
# 17
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 117        |
# |    ep_rew_mean          | -56.5      |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 2          |
# |    time_elapsed         | 867        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01111729 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | -0.00461   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 211        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0172    |
# |    value_loss           | 455        |
# ----------------------------------------
# 18
# 19
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 21
# 21
# 21
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -66.3       |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 3           |
# |    time_elapsed         | 1452        |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009119224 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.00802     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 312         |
# -----------------------------------------
# Kodun çalışma süresi: 0 saat, 24 dakika, 18 saniye
